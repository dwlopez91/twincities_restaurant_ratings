# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Food_Inspections.csv",dtype = {'FULL': 'str', 'COUNT': 'int'}) 
data.head()
# Out:
# /Users/davidlopez/anaconda3/envs/PythonData/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (9,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#            X          Y  OBJECTID HealthFacilityIDNumber FacilityCategory  \
# 0 -93.236017  44.980969      1001               LIC24381       RESTAURANT
# 1 -93.236017  44.980969      1002               LIC24381       RESTAURANT
# 2 -93.236017  44.980969      1003               LIC24381       RESTAURANT
# 3 -93.236017  44.980969      1004               LIC24381       RESTAURANT
# 4 -93.236017  44.980969      1005               LIC24381       RESTAURANT
#
#         BusinessName  RiskLevel     FullAddress  AddrNum AddrNumSuffix  ...  \
# 0  CAMDI RESTAURANTS          1  1325 4TH ST SE   1325.0           NaN  ...
# 1  CAMDI RESTAURANTS          1  1325 4TH ST SE   1325.0           NaN  ...
# ...

# %%
#trying to use on whole column for DateOfInspection ... if  I can't i'll only use year which isn't the most accurate.

import dateutil.parser

d = dateutil.parser.parse('2018-02-22T12:20:00.000Z')
print(d.strftime('%m/%d/%Y'))
# Out:
# 02/22/2018

# %%
#selecting columns I need
data1 = data[['FacilityCategory', 'BusinessName', "FullAddress", "AddrNum", "StreetName", "StreetType", "PostDir", "City", "ZipCode", "YearOfInspection", "InspectionScore"]]
data1.head()
# Out:
#   FacilityCategory       BusinessName     FullAddress  AddrNum StreetName  \
# 0       RESTAURANT  CAMDI RESTAURANTS  1325 4TH ST SE   1325.0        4TH
# 1       RESTAURANT  CAMDI RESTAURANTS  1325 4TH ST SE   1325.0        4TH
# 2       RESTAURANT  CAMDI RESTAURANTS  1325 4TH ST SE   1325.0        4TH
# 3       RESTAURANT  CAMDI RESTAURANTS  1325 4TH ST SE   1325.0        4TH
# 4       RESTAURANT  CAMDI RESTAURANTS  1325 4TH ST SE   1325.0        4TH
#
#   StreetType PostDir         City  ZipCode  YearOfInspection  InspectionScore
# 0         ST      SE  Minneapolis  55414.0              2019               82
# 1         ST      SE  Minneapolis  55414.0              2019               82
# 2         ST      SE  Minneapolis  55414.0              2019               82
# 3         ST      SE  Minneapolis  55414.0              2019               82
# 4         ST      SE  Minneapolis  55414.0              2019               82

# %%
print(data1.dtypes)
# Out:
# FacilityCategory     object
# BusinessName         object
# FullAddress          object
# AddrNum             float64
# StreetName           object
# StreetType           object
# PostDir              object
# City                 object
# ZipCode             float64
# YearOfInspection      int64
# InspectionScore       int64
# dtype: object

# %%
#sorting by year of inspection so we can drop duplicates and keep most recent inspection
data1.sort_values(by=['YearOfInspection'])
# Out:
#       FacilityCategory                     BusinessName  \
# 26709      INSTITUTION      SOUTHWEST MONTESSORI SCHOOL
# 42170       RESTAURANT                             JEFE
# 12296       RESTAURANT             EINSTEIN BROS BAGELS
# 12297       RESTAURANT             EINSTEIN BROS BAGELS
# 12298       RESTAURANT             EINSTEIN BROS BAGELS
# ...                ...                              ...
# 30976       RESTAURANT                 AHLAN RESTAURANT
# 30977       RESTAURANT                 AHLAN RESTAURANT
# 30978       RESTAURANT                 AHLAN RESTAURANT
# 30500       RESTAURANT  PANADERIA Y RESTAURANTE NATALIA
# 2966        RESTAURANT                          PAPPY'S
#
#                  FullAddress  AddrNum  StreetName StreetType PostDir  \
# 26709    5000 WASHBURN AVE S   5000.0    WASHBURN        AVE       S
# 42170         219 MAIN ST SE    219.0        MAIN         ST      SE
# 12296         720 22ND AVE S    720.0        22ND        AVE       S
# ...

# %%
#dropping duplicates of full address (should keep most recent inspection)
data2 = data1.drop_duplicates(subset="FullAddress", keep='last', inplace=False)
data2
# Out:
#       FacilityCategory                   BusinessName  \
# 65          RESTAURANT  CAMPUS CLUB OF THE UNIV OF MN
# 69             GROCERY                      CANDY JAR
# 89          RESTAURANT                      CANDYLAND
# 100         RESTAURANT                        CANTEEN
# 115         RESTAURANT                 CAPITAL GRILLE
# ...                ...                            ...
# 53313       RESTAURANT                      MCDONALDS
# 53320       RESTAURANT                      MCDONALDS
# 53324          GROCERY         MCDONALDS LIQUOR STORE
# 53387       RESTAURANT                   MCKINNEY ROE
# 53418      INSTITUTION                MCKNIGHT CENTER
#
#                    FullAddress  AddrNum     StreetName StreetType PostDir  \
# 65       300 WASHINGTON AVE SE    300.0     WASHINGTON        AVE      SE
# 69            3805 CEDAR AVE S   3805.0          CEDAR        AVE       S
# 89     27 7TH ST S #MAIN FLOOR     27.0            7TH         ST       S
# ...

# %%
data2.sort_values(by=['BusinessName'])
# Out:
#       FacilityCategory                    BusinessName  \
# 36012          GROCERY  1010 WASHINGTON WINE & SPIRITS
# 36056       RESTAURANT                      112 EATERY
# 26630       RESTAURANT           18TH GRILL RESTAURANT
# 36066       RESTAURANT                          19 BAR
# 26845       RESTAURANT       1ST CUP CAFE & RESTAURANT
# ...                ...                             ...
# 9768        RESTAURANT                 ZEN BOX IZAKAYA
# 22573       RESTAURANT                          ZETTAS
# 9769           GROCERY                    ZIPPS LIQUOR
# 29804       RESTAURANT                      ZOE'S CAFE
# 9809        RESTAURANT                     ZUMBRO CAFE
#
#                    FullAddress  AddrNum  StreetName StreetType PostDir  \
# 36012    1010 WASHINGTON AVE S   1010.0  WASHINGTON        AVE       S
# 36056             112 3RD ST N    112.0         3RD         ST       N
# 26630        1812 NICOLLET AVE   1812.0    NICOLLET        AVE     NaN
# ...

# %% [markdown]
# # YELP API

# %%
# from yelp.client import Client
import requests
import json
import pandas as pd
import numpy as np
from config import api_key
from config import google_key

# %%
data = []

headers = {'Authorization': 'Bearer %s' % api_key}

url='https://api.yelp.com/v3/businesses/search'

lat=44.9375
lon=-93.2010

for offset in range(0, 1000, 50):
    
    params = {
        'limit':50, 
        'location':'Minneapolis, MN',
#         'latitude':lat,
#         'longitude':lon,
#         'radius':10000,
        'categories':'restaurants',
        'offset':offset
        }  
    
    response=requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
        data += response.json()['businesses']
    elif response.status_code == 400:
        print('400 Bad Request')
        break
        
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# [
#     {
#         "alias": "butcher-and-the-boar-minneapolis",
#         "categories": [
#             {
#                 "alias": "newamerican",
#                 "title": "American (New)"
#             },
#             {
#                 "alias": "beergardens",
#                 "title": "Beer Gardens"
#             },
#             {
#                 "alias": "venues",
#                 "title": "Venues & Event Spaces"
#             }
#         ],
#         "coordinates": {
#             "latitude": 44.974777,
#             "longitude": -93.279792
#         },
#         "display_phone": "(612) 238-8888",
#         "distance": 1319.8158882786554,
#         "id": "G9KdODINirmdSuYaBfBppA",
#         "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/raQA0N0eKpTtW1kNPe6OcQ/o.jpg",
#         "is_closed": false,
#         "location": {
#             "address1": "1121 Hennepin Ave",
#             "address2": "",
#             "address3": "",
#             "city": "Minneapolis",
# ...

# %%
len(data)
# Out:
# 1000

# %%
i=0
yelp_list=[]
for places in data:
    yelp_id=data[i]['id']
    name=data[i]['name']
    street=data[i]['location']['address1'] 
    city=data[i]['location']['city']
    zipcode=data[i]['location']['zip_code']
    address= f'{street}, {city} {zipcode}'
    rating=data[i]['rating']
    reviews=data[i]['review_count']
    latitude=data[i]['coordinates']['latitude']
    longitude=data[i]['coordinates']['longitude']
    if data[i]['is_closed']==False:
        business_dict={"YelpID":yelp_id,"Name":name,"Latitude":latitude,"Longitude":longitude,"Address":address, "Rating":rating,"Reviews":reviews}
        yelp_list.append(business_dict)
    i+=1
    
yelp_list
# Out:
# [{'YelpID': 'G9KdODINirmdSuYaBfBppA',
#   'Name': 'Butcher & The Boar',
#   'Latitude': 44.974777,
#   'Longitude': -93.279792,
#   'Address': '1121 Hennepin Ave, Minneapolis 55403',
#   'Rating': 4.5,
#   'Reviews': 1611},
#  {'YelpID': 'zv_XJAQr9D3PNR5eHYhC5w',
#   'Name': 'Bar La Grassa',
#   'Latitude': 44.98954,
#   'Longitude': -93.278594,
#   'Address': '800 Washington Ave N, Minneapolis 55401',
#   'Rating': 4.5,
#   'Reviews': 1246},
#  {'YelpID': '6vaAze9Fxuco249L3BhEdQ',
#   'Name': '112 Eatery',
#   'Latitude': 44.98267,
#   'Longitude': -93.2716,
#   'Address': '112 N 3rd St, Minneapolis 55401',
#   'Rating': 4.5,
#   'Reviews': 1163},
#  {'YelpID': '5s2sT8ux7og5XfK-180r2g',
#   'Name': 'George & The Dragon',
#   'Latitude': 44.912151,
#   'Longitude': -93.290436,
#   'Address': '813 W 50th St, Minneapolis 55419',
#   'Rating': 4.5,
#   'Reviews': 884},
#  {'YelpID': '5olLs-K-_k_rWrrNLjvy0w',
#   'Name': 'Spoon and Stable',
#   'Latitude': 44.9854892917291,
# ...

# %%
yelp=pd.DataFrame(yelp_list)
yelp
# Out:
#                      YelpID                                     Name  \
# 0    G9KdODINirmdSuYaBfBppA                       Butcher & The Boar
# 1    zv_XJAQr9D3PNR5eHYhC5w                            Bar La Grassa
# 2    6vaAze9Fxuco249L3BhEdQ                               112 Eatery
# 3    5s2sT8ux7og5XfK-180r2g                      George & The Dragon
# 4    5olLs-K-_k_rWrrNLjvy0w                         Spoon and Stable
# ..                      ...                                      ...
# 995  LvGXa3_xmSqOoGS3fsPG5g                            New York Gyro
# 996  oomOI7VAxmcASrVS6UV_LQ                    Ariya Thai Restaurant
# 997  OsM3dIah3zF1eEFbt1FoVg  Nelson's Meats, Bakery, Deli & Catering
# 998  Z7FQJU7hq7OGhTN6ReNsIA                  Wings and Seafood To Go
# 999  IKQTWYgW_aYsBKfiYeKmbQ           Beancounter Coffeehouse & Cafe
#
#       Latitude  Longitude                                           Address  \
# ...

# %% [markdown]
# # Combine the two

# %%
#Need this so that we can alter data2
pd.options.mode.chained_assignment = None  # default='warn'

# %%
#setting the case of BusinessName to lowercase so we can match to Yelp data
data2['business_lower'] = data2['BusinessName'].str.lower()

# %%
data2['business_lower']
# Out:
# 65       campus club of the univ of mn
# 69                           candy jar
# 89                           candyland
# 100                            canteen
# 115                     capital grille
#                      ...
# 53313                        mcdonalds
# 53320                        mcdonalds
# 53324           mcdonalds liquor store
# 53387                     mckinney roe
# 53418                  mcknight center
# Name: business_lower, Length: 2225, dtype: object

# %%
#setting the case of Yelp "name" to lower so that we can match to Health Inspection Data
yelp['name_lower'] = yelp['Name'].str.lower()

# %%
yelp['name_lower']
# Out:
# 0                           butcher & the boar
# 1                                bar la grassa
# 2                                   112 eatery
# 3                          george & the dragon
# 4                             spoon and stable
#                         ...
# 995                              new york gyro
# 996                      ariya thai restaurant
# 997    nelson's meats, bakery, deli & catering
# 998                    wings and seafood to go
# 999             beancounter coffeehouse & cafe
# Name: name_lower, Length: 1000, dtype: object

# %%
#merging the two data sets - drop any data not in both
dfinal = yelp.merge(data2, how='inner', left_on='name_lower', right_on='business_lower')

# %%
dfinal
# Out:
#                      YelpID                                Name   Latitude  \
# 0    G9KdODINirmdSuYaBfBppA                  Butcher & The Boar  44.974777
# 1    zv_XJAQr9D3PNR5eHYhC5w                       Bar La Grassa  44.989540
# 2    6vaAze9Fxuco249L3BhEdQ                          112 Eatery  44.982670
# 3    5olLs-K-_k_rWrrNLjvy0w                    Spoon and Stable  44.985489
# 4    iH3FcZ4Xchx3s7fgIINaYg                       Pizzeria Lola  44.901852
# ..                      ...                                 ...        ...
# 411  N3qVkq8P42uR6VXUKVmtxw  Wholesoul a Lavender & Sage Eatery  44.939803
# 412  _RbElizwRNIG_BsLa4uS0Q                         Gastrotruck  45.012288
# 413  r5jYoCdIe6eh4zFYdksYNg                  Pair of Dice Pizza  45.009260
# 414  EjKfJ7Al5Mm0YQRNjQtqiQ                  La Alborada Market  44.948055
# 415  LvGXa3_xmSqOoGS3fsPG5g                       New York Gyro  44.949151
#
# ...

# %%
dfinal.to_csv("dfinal.csv")
